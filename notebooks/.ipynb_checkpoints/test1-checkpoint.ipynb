# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from itertools import product

df = pd.read_csv("./data/test1/measurements.csv")

print(df)
# Out:
#           dst_addr         src_addr proto  rcvd  sent        min        max  \
# 0    45.77.229.242   185.32.189.249  ICMP     3     3  30.915817  31.578678
# 1    45.77.229.242    51.159.68.135  ICMP     3     3   9.491968   9.818415
# 2    45.77.229.242  194.156.155.241  ICMP     3     3  25.917210  26.045273
# 3    45.77.229.242    62.154.179.86  ICMP     3     3  22.161655  22.274426
# 4    45.77.229.242   213.135.49.134  ICMP     3     3  26.565802  28.834862
# ..             ...              ...   ...   ...   ...        ...        ...
# 570    185.78.84.3  185.157.208.248  ICMP     3     3  44.189110  44.279610
# 571    185.78.84.3  185.157.208.248  ICMP     3     3  44.100826  44.445194
# 572    185.78.84.3  185.157.208.248  ICMP     3     3  44.244350  44.322765
# 573    185.78.84.3  185.157.208.248  ICMP     3     3  44.063194  44.247320
# 574    185.78.84.3  185.157.208.248  ICMP     3     3  44.117160  44.199210
#
#            avg     msm_id   timestamp  prb_id
# 0    31.177753  134747863  1761783925    6328
# 1     9.656543  134747863  1761783945    6817
# 2    25.986494  134747863  1761783949    6926
# 3    22.225405  134747863  1761783954    7075
# 4    27.352055  134747863  1761783952    7318
# ..         ...        ...         ...     ...
# 570  44.223904  134747855  1761786621    7464
# 571  44.305940  134747855  1761786930    7464
# 572  44.287243  134747855  1761787231    7464
# 573  44.145720  134747855  1761787536    7464
# 574  44.170420  134747855  1761787827    7464
#
# [575 rows x 11 columns]

# %%
# Duplicate rows to make symmetric
df_swapped = df.rename(columns={'src_addr':'dst_addr', 'dst_addr':'src_addr'})
df_symmetric = pd.concat([df, df_swapped], ignore_index=True)

# Aggregate averages for duplicates
agg_df = df_symmetric.groupby(['src_addr', 'dst_addr'])['avg'].mean().reset_index()

# Get all unique IPs
all_ips = sorted(set(agg_df['src_addr']).union(agg_df['dst_addr']))

# Create full Cartesian product of IPs (all possible pairs)
full_pairs = pd.DataFrame(list(product(all_ips, all_ips)), columns=['src_addr', 'dst_addr'])

# Merge with aggregated data to fill missing pairs with 0
full_df = pd.merge(full_pairs, agg_df, on=['src_addr', 'dst_addr'], how='left').fillna(0)

# Pivot for heatmap
heatmap_data = full_df.pivot(index='src_addr', columns='dst_addr', values='avg')

print(heatmap_data.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 12
#       9 all_ips = sorted(set(agg_df['src_addr']).union(agg_df['dst_addr']))
#      11 # Create full Cartesian product of IPs (all possible pairs)
# ---> 12 full_pairs = pd.DataFrame(list(product(all_ips, all_ips)), columns=['src_addr', 'dst_addr'])
#      14 # Merge with aggregated data to fill missing pairs with 0
#      15 full_df = pd.merge(full_pairs, agg_df, on=['src_addr', 'dst_addr'], how='left').fillna(0)
#
# NameError: name 'product' is not defined

# %%
plt.figure(figsize=(8, 8))
sns.heatmap(heatmap_data, annot=True, fmt=".2f", cmap="rocket")
plt.title("Aggregated ICMP Latency")
plt.xlabel("Destination Address")
plt.ylabel("Source Address")
# Out:
# Text(70.72222222222221, 0.5, 'Source Address')
